# %%
import json
import os
import matplotlib.pyplot as plt 
from mpl_toolkits.basemap import Basemap
import geopandas as gpd
import mplleaflet
from pandas import read_csv
import folium
from folium import plugins
import ijson
import numpy as np
import requests
import smopy
import pandas as pd
import folium.plugins as plugins
from pandas import compat
from folium.plugins import MarkerCluster

# %matplotlib inline

# %%
path = './test_me/user 4.csv'

# %%
df = read_csv(path, sep=';', na_values=".")

# %%
m = folium.Map(location=[39.906098, 116.206722])
folium.TileLayer('stamentoner').add_to(m)

map_osm = MarkerCluster().add_to(m)

folium.RegularPolygonMarker(
    [39.905603, 116.385069],
    popup=' On 18/10/07 at 00:06:18',
    fill_color='#132b5e',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm)

folium.RegularPolygonMarker(
    [39.905615, 116.384815],
    popup='On 18/10/07 at 00:06:58',
    fill_color='#45647d',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm)
folium.CircleMarker([39.905615, 116.384815],
                    radius=60,
                    color='#800000',
                    fill_color='#3186cc',
                   ).add_to(map_osm)

folium.RegularPolygonMarker(
    [39.900693, 116.386092],
    popup='On 18/10/07 at 00:07:00',
    fill_color='#769d96',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm)

folium.RegularPolygonMarker(
    [39.904537,  116.385341],
    popup='On 15/06/08 at 00:17:43',
    fill_color='#00FF00',
    number_of_sides=8,
    radius=10
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.904472,  116.385339],
    popup='On 10/09/08 at 00:07:48',
    fill_color='#00FF00',
    number_of_sides=8,
    radius=10
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.905101, 116.385256],
    popup='On 12/10/08 at 01:37:03',
    fill_color='#00FF00',
    number_of_sides=8,
    radius=10
    ).add_to(map_osm)
folium.CircleMarker([39.905101, 116.385256],
                    radius=80,
                    color='#800000',
                    fill_color='#3186cc',
                   ).add_to(map_osm)

folium.RegularPolygonMarker(
    [39.900902, 116.385907],
    popup='On 21/03/08 at 01:16:08',
    fill_color='#00FF00',
    number_of_sides=8,
    radius=10
    ).add_to(map_osm)

folium.CircleMarker([39.900902,  116.385907],
                    radius=150,
                    color='#800000',
                    fill_color='#3186cc',
                   ).add_to(map_osm)

folium.RegularPolygonMarker(
    [39.899991, 116.385595],
    popup='On 18/05/08 at 03:40:10',
    fill_color='#00FF00',
    number_of_sides=8,
    radius=10
    ).add_to(map_osm)
folium.CircleMarker([39.899991, 116.385595],
                    radius=30,
                    color='#800000',
                    fill_color='#3186cc',
                   ).add_to(map_osm)

folium.RegularPolygonMarker(
    [39.904908,  116.385278],
    popup='On 20/12/09 at 00:07:18',
    fill_color='#132b5e',
    number_of_sides=3,
    radius=7
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.900703,  116.385988],
    popup='On 10/04/09 at 01:13:53',
    fill_color='#45647d',
    number_of_sides=2,
    radius=7
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.90086,  116.385591],
    popup='On 10/04/09 at 01:25:38',
    fill_color='#769d96',
    number_of_sides=2,
    radius=7
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.90072,  116.386575],
    popup='On 21/03/09 at 01:17:08',
    fill_color='#769d96',
    number_of_sides=2,
    radius=7
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.926180,  116.337024],
    popup='On 06/07/09 at 13:22:49',
    fill_color='#132b5e',
    number_of_sides=2,
    radius=7
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.926175,  116.336990],
    popup='On 24/12/10 at 13:22:54',
    fill_color='#769d96',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.905662,  116.384702],
    popup='On 20/12/10 at 00:05:48',
    fill_color='#769d96',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.905308,  116.385231],
    popup='On 10/01/11 at 01:06:48',
    fill_color='#B22222',
    number_of_sides=5,
    radius=5
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.904362, 116.385323],
    popup='On 10/09/11 at 00:07:58',
    fill_color='#B22222',
    number_of_sides=5,
    radius=5
    ).add_to(map_osm)
folium.CircleMarker([39.904362, 116.385323],
                    radius=80,
                    color='#800000',
                    fill_color='#3186cc',
                   ).add_to(map_osm)

folium.RegularPolygonMarker(
    [39.904191,  116.385299],
    popup='On 10/05/11 at 00:08:13',
    fill_color='#B22222',
    number_of_sides=5,
    radius=5
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.899321, 116.386099],
    popup='On 17/09/11 at 10:03:39',
    fill_color='#B22222',
    number_of_sides=5,
    radius=5
    ).add_to(map_osm)
folium.CircleMarker([39.899321, 116.386099],
                    radius=30,
                    color='#800000',
                    fill_color='#3186cc',
                   ).add_to(map_osm)

folium.RegularPolygonMarker(
    [39.926128, 116.337046],
    popup='On 25/08/11 at 13:22:59',
    fill_color='#B22222',
    number_of_sides=5,
    radius=5
    ).add_to(map_osm)

folium.CircleMarker([39.926128, 116.337046],
                    radius=100,
                    color='#800000',
                    fill_color='#3186cc',
                   ).add_to(map_osm)

folium.RegularPolygonMarker(
    [39.926116, 116.337283],
    popup='On 23/01/12 at 13:23:04',
    fill_color='#45647d',
    number_of_sides=7,
    radius=4
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.906184, 116.206512],
    popup='On 09/03/12 at 23:32:38',
    fill_color='#769d96',
    number_of_sides=7,
    radius=4
    ).add_to(map_osm)
folium.CircleMarker([39.906184, 116.206512],
                    radius=30,
                    color='#800000',
                    fill_color='#3186cc',
                   ).add_to(map_osm)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('map_user4.html')

# %%
map_osm = folium.Map(location=[39.906098, 116.206722])

folium.RegularPolygonMarker(
    [39.905603, 116.385069],
    popup=' On 18/10/07 at 00:06:18',
    fill_color='#132b5e',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm)

folium.RegularPolygonMarker(
    [39.905615, 116.384815],
    popup='On 18/10/07 at 00:06:58',
    fill_color='#45647d',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm)
folium.CircleMarker([39.905615, 116.384815],
                    radius=60,
                    color='#800000',
                    fill_color='#3186cc',
                   ).add_to(map_osm)

folium.RegularPolygonMarker(
    [39.900693, 116.386092],
    popup='On 18/10/07 at 00:07:00',
    fill_color='#769d96',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm)

folium.RegularPolygonMarker(
    [39.904537,  116.385341],
    popup='On 15/06/08 at 00:17:43',
    fill_color='#00FF00',
    number_of_sides=8,
    radius=10
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.904472,  116.385339],
    popup='On 10/09/08 at 00:07:48',
    fill_color='#00FF00',
    number_of_sides=8,
    radius=10
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.905101, 116.385256],
    popup='On 12/10/08 at 01:37:03',
    fill_color='#00FF00',
    number_of_sides=8,
    radius=10
    ).add_to(map_osm)
folium.CircleMarker([39.905101, 116.385256],
                    radius=80,
                    color='#800000',
                    fill_color='#3186cc',
                   ).add_to(map_osm)

folium.RegularPolygonMarker(
    [39.900902, 116.385907],
    popup='On 21/03/08 at 01:16:08',
    fill_color='#00FF00',
    number_of_sides=8,
    radius=10
    ).add_to(map_osm)

folium.CircleMarker([39.900902,  116.385907],
                    radius=150,
                    color='#800000',
                    fill_color='#3186cc',
                   ).add_to(map_osm)

folium.RegularPolygonMarker(
    [39.899991, 116.385595],
    popup='On 18/05/08 at 03:40:10',
    fill_color='#00FF00',
    number_of_sides=8,
    radius=10
    ).add_to(map_osm)
folium.CircleMarker([39.899991, 116.385595],
                    radius=30,
                    color='#800000',
                    fill_color='#3186cc',
                   ).add_to(map_osm)

folium.RegularPolygonMarker(
    [39.904908,  116.385278],
    popup='On 20/12/09 at 00:07:18',
    fill_color='#132b5e',
    number_of_sides=3,
    radius=7
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.900703,  116.385988],
    popup='On 10/04/09 at 01:13:53',
    fill_color='#45647d',
    number_of_sides=2,
    radius=7
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.90086,  116.385591],
    popup='On 10/04/09 at 01:25:38',
    fill_color='#769d96',
    number_of_sides=2,
    radius=7
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.90072,  116.386575],
    popup='On 21/03/09 at 01:17:08',
    fill_color='#769d96',
    number_of_sides=2,
    radius=7
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.926180,  116.337024],
    popup='On 06/07/09 at 13:22:49',
    fill_color='#132b5e',
    number_of_sides=2,
    radius=7
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.926175,  116.336990],
    popup='On 24/12/10 at 13:22:54',
    fill_color='#769d96',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.905662,  116.384702],
    popup='On 20/12/10 at 00:05:48',
    fill_color='#769d96',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.905308,  116.385231],
    popup='On 10/01/11 at 01:06:48',
    fill_color='#B22222',
    number_of_sides=5,
    radius=5
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.904362, 116.385323],
    popup='On 10/09/11 at 00:07:58',
    fill_color='#B22222',
    number_of_sides=5,
    radius=5
    ).add_to(map_osm)
folium.CircleMarker([39.904362, 116.385323],
                    radius=80,
                    color='#800000',
                    fill_color='#3186cc',
                   ).add_to(map_osm)

folium.RegularPolygonMarker(
    [39.904191,  116.385299],
    popup='On 10/05/11 at 00:08:13',
    fill_color='#B22222',
    number_of_sides=5,
    radius=5
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.899321, 116.386099],
    popup='On 17/09/11 at 10:03:39',
    fill_color='#B22222',
    number_of_sides=5,
    radius=5
    ).add_to(map_osm)
folium.CircleMarker([39.899321, 116.386099],
                    radius=30,
                    color='#800000',
                    fill_color='#3186cc',
                   ).add_to(map_osm)

folium.RegularPolygonMarker(
    [39.926128, 116.337046],
    popup='On 25/08/11 at 13:22:59',
    fill_color='#B22222',
    number_of_sides=5,
    radius=5
    ).add_to(map_osm)

folium.CircleMarker([39.926128, 116.337046],
                    radius=100,
                    color='#800000',
                    fill_color='#3186cc',
                   ).add_to(map_osm)

folium.RegularPolygonMarker(
    [39.926116, 116.337283],
    popup='On 23/01/12 at 13:23:04',
    fill_color='#45647d',
    number_of_sides=7,
    radius=4
    ).add_to(map_osm)
folium.RegularPolygonMarker(
    [39.906184, 116.206512],
    popup='On 09/03/12 at 23:32:38',
    fill_color='#769d96',
    number_of_sides=7,
    radius=4
    ).add_to(map_osm)
folium.CircleMarker([39.906184, 116.206512],
                    radius=30,
                    color='#800000',
                    fill_color='#3186cc',
                   ).add_to(map_osm)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_osm.save('map4.html')

# %%
def mapbeinjing():
    latMinB = 39
    latMaxB = 40
    longMinB = 116
    longMaxB = 117

    m = smopy.Map((latMinB, longMinB, latMaxB, longMaxB ), z=55)
    ax = m.show_mpl(figsize=(28, 16))
    for i in range(len(df.latitude)):
        x, y = m.to_pixels(df.latitude[i], df.longitude[i])
        ax.plot(x, y, 'or', ms=10, mew=2);
    #m.show_ipython()

# %%
fig = plt.figure(figsize = (12,5)) 
plt.plot(df.latitude, df.longitude,'.r--')
#ax.axis('scaled')
plt.scatter(df.latitude, df.longitude)
plt.tight_layout()
plt.title("User 4")
#title = 'User 41'
#plt.savefig(title+'.png', bbox_inches='tight')
plt.ylabel('Longitude (degrees)')
plt.xlabel('Latitude (degrees)')
plt.show()

# %%
fig = plt.figure(figsize = (12,5))
plt.scatter(df.latitude, df.longitude)
plt.title("User 4")
#title = 'User 42'
#plt.savefig(title+'.png', bbox_inches='tight')
plt.ylabel('Longitude (degrees)')
plt.xlabel('Latitude (degrees)')
plt.show()

# %%
path2 = './test_me/user 3.csv'

# %%
ds = read_csv(path2, sep=';', na_values=".")

# %%
m = folium.Map(location=[39.906098, 116.206722])
folium.TileLayer('stamentoner').add_to(m)

map_osm1 = MarkerCluster().add_to(m)

folium.RegularPolygonMarker(
    [39.905960, 116.206300],
    popup=' On 04/08/07 at 10:14:33',
    fill_color='#132b5e',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm1)

folium.CircleMarker([39.905960, 116.206300],
                    radius=50,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm1)

folium.RegularPolygonMarker(
    [39.907409, 116.367726],
    popup='On 04/08/07 at 10:14:34',
    fill_color='#45647d',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.905631, 116.367895],
    popup='On 04/08/07 at 10:14:24',
    fill_color='#769d96',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm1)

folium.RegularPolygonMarker(
    [39.899572, 116.385684],
    popup=' On 13/07/08 at 03:40:45',
    fill_color='#132b5e',
    number_of_sides=3,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.899520, 116.385658],
    popup='On 16/05/08 at 03:40:50',
    fill_color='#45647d',
    number_of_sides=3,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.899602, 116.385616],
    popup='On 14/09/08 at 03:40:35',
    fill_color='#769d96',
    number_of_sides=3,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.905623, 116.385002],
    popup='On 10/06/08 at 00:16:13',
    fill_color='#45647d',
    number_of_sides=3,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.907247, 116.367799],
    popup='On 13/03/08 at 10:14:09',
    fill_color='#769d96',
    number_of_sides=3,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.907281, 116.367803],
    popup='On 16/07/08 at 10:14:14',
    fill_color='#45647d',
    number_of_sides=3,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.905940, 116.367922],
    popup='On 06/03/08 at 10:13:19',
    fill_color='#769d96',
    number_of_sides=3,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.906538, 116.367940],
    popup='On 16/03/08 at 10:13:34',
    fill_color='#45647d',
    number_of_sides=3,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.906538, 116.367940],
    popup='On 16/03/08 at 10:13:34',
    fill_color='#769d96',
    number_of_sides=3,
    radius=7
    ).add_to(map_osm1)

folium.RegularPolygonMarker(
    [39.898838, 116.371395],
    popup='On 11/03/09 at 10:09:29',
    fill_color='#00FF00',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.906155, 116.367916],
    popup='On 14/04/09 at 10:13:24',
    fill_color='#00FF00',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm1)

folium.CircleMarker([39.906155, 116.367916],
                    radius=300,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm1)

folium.RegularPolygonMarker(
    [39.907508, 116.367718],
    popup='On 06/05/09 at 10:14:39',
    fill_color='#00FF00',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.907317, 116.367803],
    popup='On 19/02/09 at 10:14:24',
    fill_color='#00FF00',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.907223, 116.367799],
    popup='On 17/02/09 at 10:14:04',
    fill_color='#00FF00',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.899613, 116.385725],
    popup='On 4/3/09 at 03:40:40',
    fill_color='#00FF00',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm1)

folium.CircleMarker([39.899613, 116.385725],
                    radius=100,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm1)

folium.RegularPolygonMarker(
    [39.899667, 116.385597],
    popup='On 20/02/10 at 03:40:30',
    fill_color='#800000',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.898359, 116.371449],
    popup='On 18/03/10 at 10:09:34',
    fill_color='#800000',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)
folium.CircleMarker([39.898359, 116.371449],
                    radius=100,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm1)

folium.RegularPolygonMarker(
    [39.906343, 116.367924],
    popup='On 08/03/10 at 10:13:29',
    fill_color='#800000',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.907204, 116.367796],
    popup='On 14/05/10 at 10:13:59',
    fill_color='#800000',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.907297, 116.367804],
    popup='On 07/03/10 at 10:14:19',
    fill_color='#800000',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)

folium.RegularPolygonMarker(
    [39.899361, 116.385946],
    popup='On 02/03/11 at 10:02:59',
    fill_color='#EEE8AA',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.899295, 116.385970],
    popup='On 18/03/11 at 10:03:14',
    fill_color='#EEE8AA',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.899291, 116.385999],
    popup='On 14/07/11 at 10:03:24',
    fill_color='#EEE8AA',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.905161, 116.385234],
    popup='On 10/05/11 at 01:26:58',
    fill_color='#EEE8AA',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)
folium.CircleMarker([39.905161, 116.385234],
                    radius=120,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm1)

folium.RegularPolygonMarker(
    [39.905219, 116.367814],
    popup='On 03/05/11 at 10:13:09',
    fill_color='#EEE8AA',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)

folium.RegularPolygonMarker(
    [39.904806, 116.367547],
    popup='On 13/01/12 at 10:13:04',
    fill_color='#BDB76B',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.907327, 116.367750],
    popup='On 08/03/12 at 10:14:29',
    fill_color='#BDB76B',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.907531, 116.367709],
    popup='On 17/03/12 at 10:14:44',
    fill_color='#BDB76B',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('map_user3.html')

# %%
map_osm1 = folium.Map(location=[39.906098, 116.206722])
folium.RegularPolygonMarker(
    [39.905960, 116.206300],
    popup=' On 04/08/07 at 10:14:33',
    fill_color='#132b5e',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm1)

folium.CircleMarker([39.905960, 116.206300],
                    radius=50,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm1)

folium.RegularPolygonMarker(
    [39.907409, 116.367726],
    popup='On 04/08/07 at 10:14:34',
    fill_color='#45647d',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.905631, 116.367895],
    popup='On 04/08/07 at 10:14:24',
    fill_color='#769d96',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm1)

folium.RegularPolygonMarker(
    [39.899572, 116.385684],
    popup=' On 13/07/08 at 03:40:45',
    fill_color='#132b5e',
    number_of_sides=3,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.899520, 116.385658],
    popup='On 16/05/08 at 03:40:50',
    fill_color='#45647d',
    number_of_sides=3,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.899602, 116.385616],
    popup='On 14/09/08 at 03:40:35',
    fill_color='#769d96',
    number_of_sides=3,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.905623, 116.385002],
    popup='On 10/06/08 at 00:16:13',
    fill_color='#45647d',
    number_of_sides=3,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.907247, 116.367799],
    popup='On 13/03/08 at 10:14:09',
    fill_color='#769d96',
    number_of_sides=3,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.907281, 116.367803],
    popup='On 16/07/08 at 10:14:14',
    fill_color='#45647d',
    number_of_sides=3,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.905940, 116.367922],
    popup='On 06/03/08 at 10:13:19',
    fill_color='#769d96',
    number_of_sides=3,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.906538, 116.367940],
    popup='On 16/03/08 at 10:13:34',
    fill_color='#45647d',
    number_of_sides=3,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.906538, 116.367940],
    popup='On 16/03/08 at 10:13:34',
    fill_color='#769d96',
    number_of_sides=3,
    radius=7
    ).add_to(map_osm1)

folium.RegularPolygonMarker(
    [39.898838, 116.371395],
    popup='On 11/03/09 at 10:09:29',
    fill_color='#00FF00',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.906155, 116.367916],
    popup='On 14/04/09 at 10:13:24',
    fill_color='#00FF00',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm1)

folium.CircleMarker([39.906155, 116.367916],
                    radius=300,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm1)

folium.RegularPolygonMarker(
    [39.907508, 116.367718],
    popup='On 06/05/09 at 10:14:39',
    fill_color='#00FF00',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.907317, 116.367803],
    popup='On 19/02/09 at 10:14:24',
    fill_color='#00FF00',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.907223, 116.367799],
    popup='On 17/02/09 at 10:14:04',
    fill_color='#00FF00',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.899613, 116.385725],
    popup='On 4/3/09 at 03:40:40',
    fill_color='#00FF00',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm1)

folium.CircleMarker([39.899613, 116.385725],
                    radius=100,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm1)

folium.RegularPolygonMarker(
    [39.899667, 116.385597],
    popup='On 20/02/10 at 03:40:30',
    fill_color='#800000',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.898359, 116.371449],
    popup='On 18/03/10 at 10:09:34',
    fill_color='#800000',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)
folium.CircleMarker([39.898359, 116.371449],
                    radius=100,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm1)

folium.RegularPolygonMarker(
    [39.906343, 116.367924],
    popup='On 08/03/10 at 10:13:29',
    fill_color='#800000',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.907204, 116.367796],
    popup='On 14/05/10 at 10:13:59',
    fill_color='#800000',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.907297, 116.367804],
    popup='On 07/03/10 at 10:14:19',
    fill_color='#800000',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)

folium.RegularPolygonMarker(
    [39.899361, 116.385946],
    popup='On 02/03/11 at 10:02:59',
    fill_color='#EEE8AA',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.899295, 116.385970],
    popup='On 18/03/11 at 10:03:14',
    fill_color='#EEE8AA',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.899291, 116.385999],
    popup='On 14/07/11 at 10:03:24',
    fill_color='#EEE8AA',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.905161, 116.385234],
    popup='On 10/05/11 at 01:26:58',
    fill_color='#EEE8AA',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)
folium.CircleMarker([39.905161, 116.385234],
                    radius=120,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm1)

folium.RegularPolygonMarker(
    [39.905219, 116.367814],
    popup='On 03/05/11 at 10:13:09',
    fill_color='#EEE8AA',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)

folium.RegularPolygonMarker(
    [39.904806, 116.367547],
    popup='On 13/01/12 at 10:13:04',
    fill_color='#BDB76B',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.907327, 116.367750],
    popup='On 08/03/12 at 10:14:29',
    fill_color='#BDB76B',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)
folium.RegularPolygonMarker(
    [39.907531, 116.367709],
    popup='On 17/03/12 at 10:14:44',
    fill_color='#BDB76B',
    number_of_sides=4,
    radius=7
    ).add_to(map_osm1)
map_osm1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_osm1.save('map3.html')

# %%
fig = plt.figure(figsize = (30,20))
plt.plot(ds.latitude, ds.longitude,'.r--')
plt.scatter(ds.latitude, ds.longitude)
plt.tight_layout()
plt.title("User 3")
#title = 'User 31'
#plt.savefig(title+'.png', bbox_inches='tight')
plt.ylabel('Longitude (degrees)')
plt.xlabel('Latitude (degrees)')
plt.show()

# %%
fig = plt.figure(figsize = (20,20))
plt.scatter(ds.latitude, ds.longitude)
plt.tight_layout()
plt.title("User 3")
#title = 'User 32'
#plt.savefig(title+'.png', bbox_inches='tight')
plt.ylabel('Longitude (degrees)')
plt.xlabel('Latitude (degrees)')
plt.show()

# %%
path3 = './test_me/user 2.csv'

# %%
da = read_csv(path3, sep=';', na_values=".")

# %%
m = folium.Map(location=[39.906098, 116.206722])
folium.TileLayer('stamentoner').add_to(m)

map_osm2 = MarkerCluster().add_to(m)
folium.RegularPolygonMarker(
    [39.900812, 116.385774],
    popup=' On 19/10/07 at 01:14:03',
    fill_color='#006400',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900921, 116.385609],
    popup=' On 17/10/07 at 01:14:43',
    fill_color='#006400',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900866, 116.385580],
    popup=' On 10/04/07 at 01:35:33',
    fill_color='#006400',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900943, 116.385957],
    popup=' On 21/04/07 at 01:16:13',
    fill_color='#006400',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.899289, 116.385991],
    popup=' On 19/08/07 at 10:03:22',
    fill_color='#006400',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.899321, 116.386036],
    popup=' On 27/10/07 at 10:03:34',
    fill_color='#006400',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)

folium.RegularPolygonMarker(
    [39.905241, 116.385219],
    popup=' On 14/08/08 at 02:46:53',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900895, 116.385589],
    popup=' On 10/04/08 at 01:14:28',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900920, 116.385552],
    popup=' On 10/07/08 at 01:14:38',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900866, 116.385559],
    popup=' On 10/03/08 at 01:14:18',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900931, 116.385619],
    popup=' On 10/04/08 at 01:14:48',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900878, 116.385815],
    popup=' On 23/04/08 at 01:15:58',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900941, 116.385991],
    popup=' On 15/03/08 at 01:16:23',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900881, 116.386157],
    popup=' On 25/04/08 at 01:16:33',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.905241, 116.385219],
    popup=' On 14/08/08 at 02:46:53',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900895, 116.385589],
    popup=' On 10/04/08 at 01:14:28',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900920, 116.385552],
    popup=' On 10/07/08 at 01:14:38',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900866, 116.385559],
    popup=' On 10/03/08 at 01:14:18',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900931, 116.385619],
    popup=' On 10/04/08 at 01:14:48',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900878, 116.385815],
    popup=' On 23/04/08 at 01:15:58',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900941, 116.385991],
    popup=' On 15/03/08 at 01:16:23',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900881, 116.386157],
    popup=' On 25/04/08 at 01:16:33',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.CircleMarker([39.900881, 116.386157],
                    radius=150,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm2)

folium.RegularPolygonMarker(
    [39.899934, 116.385580],
    popup=' On 08/07/08 at 03:40:15',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.CircleMarker([39.899934, 116.385580],
                    radius=80,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm2)

folium.RegularPolygonMarker(
    [39.899294, 116.386014],
    popup=' On 27/11/08 at 10:03:29',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.CircleMarker([39.899294, 116.386014],
                    radius=60,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm2)

folium.RegularPolygonMarker(
    [39.900891, 116.385854],
    popup=' On 21/04/09 at 01:16:03',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900915, 116.385574],
    popup=' On 10/04/09 at 01:14:33',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900936, 116.385630],
    popup=' On 10/08/09 at 01:14:56',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900947, 116.385686],
    popup=' On 10/04/09 at 01:15:11',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900925, 116.385693],
    popup=' On 10/03/09 at 01:15:18',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900742, 116.386569],
    popup=' On 14/03/09 at 01:17:03',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900812, 116.386366],
    popup=' On 21/02/09 at 01:16:38',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900639, 116.386575],
    popup=' On 21/03/09 at 01:17:08',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900639, 116.386575],
    popup=' On 10/04/09 at 01:17:13',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.899759, 116.385632],
    popup=' On 21/06/09 at 03:40:20',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.899712, 116.385598],
    popup=' On 10/02/09 at 03:40:25',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)

folium.RegularPolygonMarker(
    [39.899289, 116.385991],
    popup=' On 17/11/10 at 10:03:19',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900878, 116.385534],
    popup=' On 17/03/10 at 01:14:23',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900942, 116.385627],
    popup=' On 16/02/10 at 01:14:58',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900947, 116.385686],
    popup=' On 10/04/10 at 01:15:08',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900941, 116.385692],
    popup=' On 10/03/10 at 01:15:13',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900849, 116.385624],
    popup=' On 10/04/10 at 01:15:43',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900958, 116.385969],
    popup=' On 20/03/10 at 01:16:18',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900817, 116.386486],
    popup=' On 20/02/10 at 01:16:43',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900049, 116.385587],
    popup=' On 10/05/10 at 03:40:00',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900002, 116.385602],
    popup=' On 09/04/10 at 03:40:05',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.905543, 116.385206],
    popup=' On 10/06/10 at 00:26:28',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.CircleMarker([39.905543, 116.385206],
                    radius=90,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm2)

folium.RegularPolygonMarker(
    [39.900709, 116.385919],
    popup=' On 18/06/10 at 01:13:58',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)

folium.RegularPolygonMarker(
    [39.905631, 116.384964],
    popup=' On 24/10/11 at 00:12:08',
    fill_color='#000080',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900946, 116.385650],
    popup=' On 10/03/11 at 01:15:03',
    fill_color='#000080',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900883, 116.385571],
    popup=' On 10/04/11 at 01:15:23',
    fill_color='#000080',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900864, 116.385766],
    popup=' On 23/04/11 at 01:15:53',
    fill_color='#000080',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900775, 116.386546],
    popup=' On 20/04/11 at 01:16:58',
    fill_color='#000080',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900862, 116.386485],
    popup=' On 18/03/11 at 01:16:48',
    fill_color='#000080',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.899313, 116.385968],
    popup=' On 13/05/11  10:03:09',
    fill_color='#000080',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)

folium.RegularPolygonMarker(
    [39.900936, 116.385630],
    popup='On 25/11/12 at 01:14:53',
    fill_color='#45647d',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900875, 116.385540],
    popup='On 10/03/12 at 01:15:28',
    fill_color='#45647d',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900838, 116.385675],
    popup='On 10/03/12 at 01:15:48',
    fill_color='#45647d',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900941, 116.386001],
    popup='On 20/02/12 at 01:16:28',
    fill_color='#45647d',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900836, 116.386497],
    popup='On 21/02/12 at 01:16:53',
    fill_color='#45647d',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.899351, 116.385974],
    popup='On 05/03/12 at 10:03:04',
    fill_color='#45647d',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm2)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('map_user2.html')

# %%
map_osm2 = folium.Map(location=[39.906098, 116.206722])
folium.RegularPolygonMarker(
    [39.900812, 116.385774],
    popup=' On 19/10/07 at 01:14:03',
    fill_color='#006400',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900921, 116.385609],
    popup=' On 17/10/07 at 01:14:43',
    fill_color='#006400',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900866, 116.385580],
    popup=' On 10/04/07 at 01:35:33',
    fill_color='#006400',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900943, 116.385957],
    popup=' On 21/04/07 at 01:16:13',
    fill_color='#006400',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.899289, 116.385991],
    popup=' On 19/08/07 at 10:03:22',
    fill_color='#006400',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.899321, 116.386036],
    popup=' On 27/10/07 at 10:03:34',
    fill_color='#006400',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)

folium.RegularPolygonMarker(
    [39.905241, 116.385219],
    popup=' On 14/08/08 at 02:46:53',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900895, 116.385589],
    popup=' On 10/04/08 at 01:14:28',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900920, 116.385552],
    popup=' On 10/07/08 at 01:14:38',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900866, 116.385559],
    popup=' On 10/03/08 at 01:14:18',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900931, 116.385619],
    popup=' On 10/04/08 at 01:14:48',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900878, 116.385815],
    popup=' On 23/04/08 at 01:15:58',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900941, 116.385991],
    popup=' On 15/03/08 at 01:16:23',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900881, 116.386157],
    popup=' On 25/04/08 at 01:16:33',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.905241, 116.385219],
    popup=' On 14/08/08 at 02:46:53',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900895, 116.385589],
    popup=' On 10/04/08 at 01:14:28',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900920, 116.385552],
    popup=' On 10/07/08 at 01:14:38',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900866, 116.385559],
    popup=' On 10/03/08 at 01:14:18',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900931, 116.385619],
    popup=' On 10/04/08 at 01:14:48',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900878, 116.385815],
    popup=' On 23/04/08 at 01:15:58',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900941, 116.385991],
    popup=' On 15/03/08 at 01:16:23',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900881, 116.386157],
    popup=' On 25/04/08 at 01:16:33',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.CircleMarker([39.900881, 116.386157],
                    radius=150,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm2)

folium.RegularPolygonMarker(
    [39.899934, 116.385580],
    popup=' On 08/07/08 at 03:40:15',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.CircleMarker([39.899934, 116.385580],
                    radius=80,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm2)

folium.RegularPolygonMarker(
    [39.899294, 116.386014],
    popup=' On 27/11/08 at 10:03:29',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.CircleMarker([39.899294, 116.386014],
                    radius=60,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm2)

folium.RegularPolygonMarker(
    [39.900891, 116.385854],
    popup=' On 21/04/09 at 01:16:03',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900915, 116.385574],
    popup=' On 10/04/09 at 01:14:33',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900936, 116.385630],
    popup=' On 10/08/09 at 01:14:56',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900947, 116.385686],
    popup=' On 10/04/09 at 01:15:11',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900925, 116.385693],
    popup=' On 10/03/09 at 01:15:18',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900742, 116.386569],
    popup=' On 14/03/09 at 01:17:03',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900812, 116.386366],
    popup=' On 21/02/09 at 01:16:38',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900639, 116.386575],
    popup=' On 21/03/09 at 01:17:08',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900639, 116.386575],
    popup=' On 10/04/09 at 01:17:13',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.899759, 116.385632],
    popup=' On 21/06/09 at 03:40:20',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.899712, 116.385598],
    popup=' On 10/02/09 at 03:40:25',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)

folium.RegularPolygonMarker(
    [39.899289, 116.385991],
    popup=' On 17/11/10 at 10:03:19',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900878, 116.385534],
    popup=' On 17/03/10 at 01:14:23',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900942, 116.385627],
    popup=' On 16/02/10 at 01:14:58',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900947, 116.385686],
    popup=' On 10/04/10 at 01:15:08',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900941, 116.385692],
    popup=' On 10/03/10 at 01:15:13',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900849, 116.385624],
    popup=' On 10/04/10 at 01:15:43',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900958, 116.385969],
    popup=' On 20/03/10 at 01:16:18',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900817, 116.386486],
    popup=' On 20/02/10 at 01:16:43',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900049, 116.385587],
    popup=' On 10/05/10 at 03:40:00',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900002, 116.385602],
    popup=' On 09/04/10 at 03:40:05',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.905543, 116.385206],
    popup=' On 10/06/10 at 00:26:28',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.CircleMarker([39.905543, 116.385206],
                    radius=90,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm2)

folium.RegularPolygonMarker(
    [39.900709, 116.385919],
    popup=' On 18/06/10 at 01:13:58',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)

folium.RegularPolygonMarker(
    [39.905631, 116.384964],
    popup=' On 24/10/11 at 00:12:08',
    fill_color='#000080',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900946, 116.385650],
    popup=' On 10/03/11 at 01:15:03',
    fill_color='#000080',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900883, 116.385571],
    popup=' On 10/04/11 at 01:15:23',
    fill_color='#000080',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900864, 116.385766],
    popup=' On 23/04/11 at 01:15:53',
    fill_color='#000080',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900775, 116.386546],
    popup=' On 20/04/11 at 01:16:58',
    fill_color='#000080',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900862, 116.386485],
    popup=' On 18/03/11 at 01:16:48',
    fill_color='#000080',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.899313, 116.385968],
    popup=' On 13/05/11  10:03:09',
    fill_color='#000080',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm2)

folium.RegularPolygonMarker(
    [39.900936, 116.385630],
    popup='On 25/11/12 at 01:14:53',
    fill_color='#45647d',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900875, 116.385540],
    popup='On 10/03/12 at 01:15:28',
    fill_color='#45647d',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900838, 116.385675],
    popup='On 10/03/12 at 01:15:48',
    fill_color='#45647d',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900941, 116.386001],
    popup='On 20/02/12 at 01:16:28',
    fill_color='#45647d',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.900836, 116.386497],
    popup='On 21/02/12 at 01:16:53',
    fill_color='#45647d',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm2)
folium.RegularPolygonMarker(
    [39.899351, 116.385974],
    popup='On 05/03/12 at 10:03:04',
    fill_color='#45647d',
    number_of_sides=5,
    radius=6
    ).add_to(map_osm2)

map_osm2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_osm2.save('map2.html')

# %%
fig = plt.figure(figsize = (30,20))
plt.plot(da.latitude, da.longitude,'.r--')
plt.scatter(da.latitude, da.longitude)
plt.tight_layout()
plt.title("User 2")
#title = 'User 21'
#plt.savefig(title+'.png', bbox_inches='tight')
plt.ylabel('Longitude (degrees)')
plt.xlabel('Latitude (degrees)')
plt.show()

# %%
fig = plt.figure(figsize = (20,20))
plt.scatter(da.latitude, da.longitude)
plt.tight_layout()
plt.title("User 2")
#title = 'User 22'
#plt.savefig(title+'.png', bbox_inches='tight')
plt.ylabel('Longitude (degrees)')
plt.xlabel('Latitude (degrees)')
plt.show()

# %%
path4 = './test_me/user1.csv'

# %%
db = read_csv(path4, sep=';', na_values=".")

# %%
m = folium.Map(
    location=[np.mean(db.latitude), np.mean(db.longitude)],
    tiles='stamentoner',
    zoom_start=10
)

marker_cluster = MarkerCluster(
    name='clustered icons',
    overlay=True,
    control=True,
    icon_create_function=None
)
    
for k in range(44):
    location = db.latitude[k], db.longitude[k]
    details = db.date[k], db.time[k]
    marker = folium.Marker(location=location)
    popup = 'time:{}<br>date:{}'.format(details[1], details[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=[39.906098, 116.206722])
folium.TileLayer('stamentoner').add_to(m)

map_osm3 = MarkerCluster(
overlay=True,
control=True,).add_to(m)
folium.LayerControl().add_to(m)

folium.RegularPolygonMarker(
    [39.906098, 116.206722],
    popup=' On 09/05/07 at 23:32:08',
    fill_color='#006400',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.906124, 116.206598],
    popup=' On 09/06/07 at 23:32:33',
    fill_color='#006400',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905923, 116.205999],
    popup=' On 09/08/07 at 23:32:58',
    fill_color='#006400',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905823, 116.206066],
    popup=' On 09/09/07 at 23:33:33',
    fill_color='#006400',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)

folium.RegularPolygonMarker(
    [39.906108, 116.206647],
    popup=' On 09/03/08 at 23:32:13',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.906077, 116.206678],
    popup=' On 09/03/08 at 23:32:28',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905818, 116.206010],
    popup=' On 29/02/08 at 23:33:28',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905664, 116.384631],
    popup=' On 10/07/08 at 00:05:43',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905921, 116.206233],
    popup=' On 09/03/08 at 23:33:48',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.904698, 116.385307],
    popup=' On 17/04/08 at 00:07:33',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.904856, 116.385279],
    popup=' On 10/06/08 at 00:07:23',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.904698, 116.385307],
    popup=' On 17/04/08 at 00:07:33',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)

folium.RegularPolygonMarker(
    [39.906119, 116.206557],
    popup=' On 19/02/09 at 23:32:18',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.906194, 116.206352],
    popup=' On 09/02/09 at 23:32:43',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.906046, 116.206099],
    popup=' On 04/03/09 at 23:32:53',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905880, 116.205977],
    popup=' On 09/03/09 at 23:33:03',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905977, 116.206359],
    popup=' On 09/10/09 at 23:33:58',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)

folium.CircleMarker([39.905977, 116.206359],
                    radius=100,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm3)

folium.RegularPolygonMarker(
    [39.905690, 116.384583],
    popup=' On 24/11/09 at 00:05:38',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905847, 116.206145],
    popup=' On 09/03/09 at 23:33:38',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905583, 116.385152],
    popup=' On 10/10/09 at 00:11:23',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905043, 116.385271],
    popup=' On 10/10/09 at 00:07:08',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.904296, 116.385335],
    popup=' On 10/07/09 at 00:08:03',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.904296, 116.385335],
    popup=' On ',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.900649, 116.386426],
    popup=' On 10/01/09 at 01:13:43',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.904618, 116.385330],
    popup=' On 10/10/09 at 00:07:38',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)

folium.RegularPolygonMarker(
    [39.906078, 116.206755],
    popup=' On 04/03/10 at 23:32:23',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.906162, 116.206231],
    popup=' On 14/03/10 at 23:32:48',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905610, 116.384752],
    popup=' On 17/09/10 at 00:06:53',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905855, 116.205941],
    popup=' On 24/02/10 at 23:33:08',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905887, 116.206187],
    popup=' On 21/02/10 at 23:33:43',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905887, 116.206187],
    popup=' On 21/02/10 at 23:33:43',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905617, 116.384887],
    popup=' On 16/07/10 at 00:06:03',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.904976, 116.385278],
    popup=' On 03/07/10 at 00:07:13',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.904976, 116.385278],
    popup=' On 03/07/10 at 00:07:13',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905371, 116.385213],
    popup=' On 20/08/10 at 01:26:53',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.904756, 116.385305],
    popup=' On 10/04/10 at 00:07:28',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.904418, 116.385326],
    popup=' On 10/08/10 at 00:07:53',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.904243, 116.385314],
    popup=' On 10/06/10 at 00:08:08',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)


folium.RegularPolygonMarker(
    [39.905820, 116.205906],
    popup=' On 10/04/11 at 23:33:13',
    fill_color='#000080',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905808, 116.205976],
    popup=' On 09/03/11 at 23:33:23',
    fill_color='#000080',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905406, 116.385215],
    popup=' On 05/03/11 at 01:16:38',
    fill_color='#000080',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)

folium.RegularPolygonMarker(
    [39.905801, 116.205952],
    popup=' On 01/03/12 at 23:33:18',
    fill_color='#A9A9A9',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905475, 116.385194],
    popup=' On 15/04/12 at 01:06:33',
    fill_color='#A9A9A9',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)

folium.CircleMarker([39.905475, 116.385194],
                    radius=120,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm3)

folium.RegularPolygonMarker(
    [39.900595, 116.386606],
    popup=' On 10/08/12 at 10:03:53',
    fill_color='#A9A9A9',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)

folium.CircleMarker([39.900595, 116.386606],
                    radius=50,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm3)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('map_user1.html')

# %%
map_osm3 = folium.Map(location=[39.906098, 116.206722])
folium.RegularPolygonMarker(
    [39.906098, 116.206722],
    popup=' On 09/05/07 at 23:32:08',
    fill_color='#006400',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.906124, 116.206598],
    popup=' On 09/06/07 at 23:32:33',
    fill_color='#006400',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905923, 116.205999],
    popup=' On 09/08/07 at 23:32:58',
    fill_color='#006400',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905823, 116.206066],
    popup=' On 09/09/07 at 23:33:33',
    fill_color='#006400',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)

folium.RegularPolygonMarker(
    [39.906108, 116.206647],
    popup=' On 09/03/08 at 23:32:13',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.906077, 116.206678],
    popup=' On 09/03/08 at 23:32:28',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905818, 116.206010],
    popup=' On 29/02/08 at 23:33:28',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905664, 116.384631],
    popup=' On 10/07/08 at 00:05:43',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905921, 116.206233],
    popup=' On 09/03/08 at 23:33:48',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.904698, 116.385307],
    popup=' On 17/04/08 at 00:07:33',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.904856, 116.385279],
    popup=' On 10/06/08 at 00:07:23',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.904698, 116.385307],
    popup=' On 17/04/08 at 00:07:33',
    fill_color='#8B0000',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)

folium.RegularPolygonMarker(
    [39.906119, 116.206557],
    popup=' On 19/02/09 at 23:32:18',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.906194, 116.206352],
    popup=' On 09/02/09 at 23:32:43',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.906046, 116.206099],
    popup=' On 04/03/09 at 23:32:53',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905880, 116.205977],
    popup=' On 09/03/09 at 23:33:03',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905977, 116.206359],
    popup=' On 09/10/09 at 23:33:58',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)

folium.CircleMarker([39.905977, 116.206359],
                    radius=100,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm3)

folium.RegularPolygonMarker(
    [39.905690, 116.384583],
    popup=' On 24/11/09 at 00:05:38',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905847, 116.206145],
    popup=' On 09/03/09 at 23:33:38',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905583, 116.385152],
    popup=' On 10/10/09 at 00:11:23',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905043, 116.385271],
    popup=' On 10/10/09 at 00:07:08',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.904296, 116.385335],
    popup=' On 10/07/09 at 00:08:03',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.904296, 116.385335],
    popup=' On ',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.900649, 116.386426],
    popup=' On 10/01/09 at 01:13:43',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.904618, 116.385330],
    popup=' On 10/10/09 at 00:07:38',
    fill_color='#F0E68C',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)

folium.RegularPolygonMarker(
    [39.906078, 116.206755],
    popup=' On 04/03/10 at 23:32:23',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.906162, 116.206231],
    popup=' On 14/03/10 at 23:32:48',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905610, 116.384752],
    popup=' On 17/09/10 at 00:06:53',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905855, 116.205941],
    popup=' On 24/02/10 at 23:33:08',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905887, 116.206187],
    popup=' On 21/02/10 at 23:33:43',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905887, 116.206187],
    popup=' On 21/02/10 at 23:33:43',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905617, 116.384887],
    popup=' On 16/07/10 at 00:06:03',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.904976, 116.385278],
    popup=' On 03/07/10 at 00:07:13',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.904976, 116.385278],
    popup=' On 03/07/10 at 00:07:13',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905371, 116.385213],
    popup=' On 20/08/10 at 01:26:53',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.904756, 116.385305],
    popup=' On 10/04/10 at 00:07:28',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.904418, 116.385326],
    popup=' On 10/08/10 at 00:07:53',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.904243, 116.385314],
    popup=' On 10/06/10 at 00:08:08',
    fill_color='#0000ff',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)


folium.RegularPolygonMarker(
    [39.905820, 116.205906],
    popup=' On 10/04/11 at 23:33:13',
    fill_color='#000080',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905808, 116.205976],
    popup=' On 09/03/11 at 23:33:23',
    fill_color='#000080',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905406, 116.385215],
    popup=' On 05/03/11 at 01:16:38',
    fill_color='#000080',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)

folium.RegularPolygonMarker(
    [39.905801, 116.205952],
    popup=' On 01/03/12 at 23:33:18',
    fill_color='#A9A9A9',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)
folium.RegularPolygonMarker(
    [39.905475, 116.385194],
    popup=' On 15/04/12 at 01:06:33',
    fill_color='#A9A9A9',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)

folium.CircleMarker([39.905475, 116.385194],
                    radius=120,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm3)

folium.RegularPolygonMarker(
    [39.900595, 116.386606],
    popup=' On 10/08/12 at 10:03:53',
    fill_color='#A9A9A9',
    number_of_sides=4,
    radius=6
    ).add_to(map_osm3)

folium.CircleMarker([39.900595, 116.386606],
                    radius=50,
                    color='#3186cc',
                    fill_color='#3186cc',
                   ).add_to(map_osm3)

map_osm3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_osm3.save('map1.html')

# %%
plt.figure(figsize = (20,20))
plt.scatter(db.latitude, db.longitude)
plt.plot(db.latitude, db.longitude, '.r--')
plt.tight_layout()
#title = 'User 11'
plt.title("User 1")
#plt.savefig(title+'.png', bbox_inches='tight')
plt.ylabel('Longitude (degrees)')
plt.xlabel('Latitude (degrees)')
plt.show()

# %%
plt.figure(figsize = (20,15))
plt.scatter(db.latitude, db.longitude)
plt.tight_layout()
#title = 'User 12'
plt.title("User 1")
#plt.savefig(title+'.png', bbox_inches='tight')
plt.ylabel('Longitude (degrees)')
plt.xlabel('Latitude (degrees)')
plt.show()

# %%
path = './INPUT_FOLDER/E1107.csv'
da = read_csv(path, sep=';', na_values=".")

# %%
m = folium.Map(
    location=[39.951850, 116.455150],
    zoom_start=11
)

marker_cluster = MarkerCluster(
    name='clustered icons',
    overlay=True,
    control=True,
    icon_create_function=None
)
    
for k in range(len(da.Latitude)):
    location = da.Latitude[k], da.Longitude[k]
    marker = folium.Marker(location=location)
    popup = 'Date:{}<br>Time:{}<br>Latitude:{}<br>Longitude:{}'.format(da.Date[k], da.Time[k], da.Latitude[k], da.Longitude[k])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)
m.save('map_user1.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(
    location=[39.951850, 116.455150],
    zoom_start=12
)

lines = [
    {
        'coordinates': [
            [116.338800,39.977783],
            [116.339383,39.976800],
            ],
        'dates': [
            '2017-08-05T01:33:30',
            '2017-08-05T01:40:07',
        ],
        'color': 'red',
        'weight': 15,
    },
    {
        'coordinates': [    
            [116.339383,39.976800],
            [116.338750,39.978917],
        ],
        'dates': [
            '2017-08-05T01:40:07',
            '2017-08-05T01:45:22',
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [    
            [116.338750,39.978917],
            [116.337467,39.981717]
            ],
        'dates': [
            '2017-08-05T01:45:22',
            '2017-08-05T01:50:26'
        ],
        'color': 'white'
    },
    {
        'coordinates': [
            [116.337467,39.981717],
            [116.337217,39.981767]
            ],
        'dates': [
            '2017-08-05T01:50:26',
            '2017-08-05T02:17:08'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            [116.337217,39.981767],
            [116.339433,39.981883]
            ],
        'dates': [
            '2017-08-05T02:17:08',
            '2017-08-05T02:20:15'
        ],
        'color': 'yellow'
    },
    {
        'coordinates': [
            [116.339433,39.981883],
            [116.341783,39.980450]
            ],
        'dates': [
            '2017-08-05T02:20:15',
            '2017-08-05T02:25:16'
        ],
        'color': 'orange'
    },
    {
        'coordinates': [
            
            [116.341783,39.980450],
            [116.345433,39.979833]
            ],
        'dates': [
            '2017-08-05T02:25:16',
            '2017-08-05T02:30:07'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.345433,39.979833],
            [116.347367,39.979300]
            ],
        'dates': [
            '2017-08-05T02:30:07',
            '2017-08-05T04:03:17'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            [116.347367,39.979300],
            [116.342017,39.979983]
            ],
        'dates': [
            '2017-08-05T04:03:17',
            '2017-08-05T04:07:36'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            [116.342017,39.979983],
            [116.339050,39.980450]
            ],
        'dates': [
            '2017-08-05T04:07:36',
            '2017-08-05T04:11:27'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.339050,39.980450],
            [116.338817,39.980467]
            ],
        'dates': [
            '2017-08-05T04:11:27',
            '2017-08-05T04:33:53'
        ],
        'color': 'yellow'
    },
    {
        'coordinates': [
            [116.338817,39.980467],
            [116.339317,39.979833]
            ],
        'dates': [
            '2017-08-05T04:33:53',
            '2017-08-05T04:35:06'
        ],
        'color': 'black'
    },
    {
        'coordinates': [
            [116.339317,39.979833],
            [116.342883,39.979917]
            ],
        'dates': [
            '2017-08-05T04:35:06',
            '2017-08-05T04:40:23'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [

            [116.342883,39.979917], 
            [116.345433,39.979750]
            ],
        'dates': [
            '2017-08-05T04:40:23',
            '2017-08-05T04:43:35'
        ],
        'color': 'red'
    },
    {
        'coordinates': [

            [116.345433,39.979750],
            [116.346050,39.979650]
            ],
        'dates': [
            '2017-08-05T04:43:35',
            '2017-08-05T07:25:01'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            
            [116.346050,39.979650],
            [116.347033,39.978750]
            ],
        'dates': [
            '2017-08-05T07:25:01',
            '2017-08-05T07:28:00'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            
            [116.347033,39.978750],         
            [116.347350,39.975800]
            ],
        'dates': [
            '2017-08-05T07:28:00',
            '2017-08-05T07:32:02'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            
            [116.347350,39.975800],
            [116.346617,39.973350]
            ],
        'dates': [
            '2017-08-05T07:32:02',
            '2017-08-05T07:36:53'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            
            [116.346617,39.973350],
            [116.346667,39.973100]
            ],
        'dates': [
            '2017-08-05T07:36:53',
            '2017-08-05T07:45:13'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            
            [116.346667,39.973100],
            [116.346883,39.963083]
            ],
        'dates': [
            '2017-08-05T07:45:13',
            '2017-08-05T07:48:11'
        ],
        'color': 'yellow'
    },
    {
        'coordinates': [
            
            [116.346883,39.963083],
            [116.352183,39.956533]
            ],
        'dates': [
            '2017-08-05T07:48:11',
            '2017-08-05T07:51:16'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            
            [116.352183,39.956533],
            [116.361117,39.956700]
            ],
        'dates': [
            '2017-08-05T07:51:16',
            '2017-08-05T07:55:50'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.361117,39.956700],
            [116.363483,39.956767]
            ],
        'dates': [
            '2017-08-05T07:55:50',
            '2017-08-05T08:00:24'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            [116.363483,39.956767],
            [116.367033,39.956650]
            ],
        'dates': [
            '2017-08-05T08:00:24',
            '2017-08-05T08:04:48'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            
            [116.367033,39.956650],
            [116.369983,39.955783]
            ],
        'dates': [
            '2017-08-05T08:04:48',
            '2017-08-05T08:17:16'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.369983,39.955783],
            [116.372700,39.957300]
            ],
        'dates': [
            '2017-08-05T08:17:16',
            '2017-08-05T08:22:16'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            [116.372700,39.957300],
            [116.372983,39.950967]
            ],
        'dates': [
            '2017-08-05T08:22:16',
            '2017-08-05T08:32:09'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [ 
            [116.372983,39.950967],
            [116.372650,39.948050]
            ],
        'dates': [
            '2017-08-05T08:32:09',
            '2017-08-05T08:35:17'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            
            [116.372650,39.948050],
            [116.387417,39.946600]
            ],
        'dates': [
            '2017-08-05T08:35:17',
            '2017-08-05T08:40:36'
        ],
        'color': 'yellow'
    },
    {
        'coordinates': [
            
            [116.387417,39.946600],
            [116.387533,39.946283]
            ],
        'dates': [
            '2017-08-05T08:40:36',
            '2017-08-05T08:56:35'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            
            [116.387533,39.946283],
            [116.387783,39.946133]
            ],
        'dates': [
            '2017-08-05T08:56:35',
            '2017-08-05T09:00:52'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            
            [116.387783,39.946133],
            [116.455133,39.904517]
            ],
        'dates': [
            '2017-08-05T09:00:52',
            '2017-08-05T09:48:30'
        ],
        'color': 'orange'
    },
    {
        'coordinates': [
            
            [116.455133,39.904517],
            [116.457117,39.905467]
            ],
        'dates': [
            '2017-08-05T09:48:30',
            '2017-08-05T09:52:00'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            
            [116.457117,39.905467],
            [116.454767,39.874733]
            ],
        'dates': [
            '2017-08-05T09:52:00',
            '2017-08-05T09:59:35'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            
            [116.454767,39.874733],
            [116.466167,39.846700]
            ],
        'dates': [
            '2017-08-05T09:59:35',
            '2017-08-05T10:04:09'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            
            [116.466167,39.846700],
            [116.472383,39.807650]
            ],
        'dates': [
            '2017-08-05T10:04:09',
            '2017-08-05T10:10:28'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            
            [116.472383,39.807650],
            [116.478350,39.799683]
            ],
        'dates': [
            '2017-08-05T10:10:28',
            '2017-08-05T10:14:55'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            
            [116.478350,39.799683],
            [116.485367,39.798917]
            ],
        'dates': [
            '2017-08-05T10:14:55',
            '2017-08-05T10:19:17'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            
            [116.485367,39.798917],
            [116.467367,39.806583]
            ],
        'dates': [
            '2017-08-05T10:19:17',
            '2017-08-05T10:37:12'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            
            [116.467367,39.806583],
            [116.449583,39.821667]
            ],
        'dates': [
            '2017-08-05T10:37:12',
            '2017-08-05T10:41:51'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            
            [116.449583,39.821667],
            [116.440650,39.835167]
            ],
        'dates': [
            '2017-08-05T10:41:51',
            '2017-08-05T10:50:34'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            
            [116.440650,39.835167],
            [116.439400,39.851550]
            ],
        'dates': [
            '2017-08-05T10:50:34',
            '2017-08-05T10:55:07'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            
            [116.439400,39.851550],
            [116.438917,39.857333]
            ],
        'dates': [
            '2017-08-05T10:55:07',
            '2017-08-05T11:02:44'
        ],
        'color': 'black'
    },
    {
        'coordinates': [
            
            [116.438917,39.857333],
            [116.455867,39.898667]
            ],
        'dates': [
            '2017-08-05T11:02:44',
            '2017-08-05T11:11:15'
        ],
        'color': 'yellow'
    },
    {
        'coordinates': [
            
            [116.455867,39.898667],
            [116.455150,39.951850]
            ],
        'dates': [
            '2017-08-05T11:11:15',
            '2017-08-05T11:20:00'
        ],
        'color': 'orange'
    },
    {
        'coordinates': [
            
            [116.455150,39.951850],
            [116.376283,39.967083]
            ],
        'dates': [
            '2017-08-05T11:20:00',
            '2017-08-05T11:30:24'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            
            [116.376283,39.967083],
            [116.359283,39.971667]
            ],
        'dates': [
            '2017-08-05T11:30:24',
            '2017-08-05T11:40:13'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            
            [116.359283,39.971667],
            [116.347333,39.980350]
            ],
        'dates': [
            '2017-08-05T11:40:13',
            '2017-08-05T11:50:21'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            
            [116.347333,39.980350],
            [116.344417,39.978617]
            ],
        'dates': [
            '2017-08-05T11:50:21',
            '2017-08-05T15:45:08'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            
            [116.344417,39.978617],
            [116.340933,39.977950]
            ],
        'dates': [
            '2017-08-05T15:45:08',
            '2017-08-05T15:50:14'
        ],
        'color': 'black'
    },
    {
        'coordinates': [
            
            [116.340933,39.977950],
            [116.338800,39.976550]
            ],
        'dates': [
            '2017-08-05T15:50:14',
            '2017-08-05T15:55:19'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            
            [116.338800,39.976550],
            [116.337600,39.976967]
        ],
        'dates': [
            '2017-08-05T15:55:19',
            '2017-08-05T15:01:20'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.337600,39.976967],
            [116.205999, 39.905923],
        ],
        'dates': [
            '2017-08-05T15:01:20',
            '2017-08-05T15:11:20'
        ],
        'color': 'blue'
    },
    
]


features = [
    {
        'type': 'Feature',
        'geometry': {
            'type': 'LineString',
            'coordinates': line['coordinates'],
        },
        'properties': {
            'times': line['dates'],
            'style': {
                'color': line['color'],
                'weight': line['weight'] if 'weight' in line else 8
            }
        }
    }
    for line in lines
]

plugins.TimestampedGeoJson({
    'type': 'FeatureCollection',
    'features': features,
}, period='PT1M', loop=True, add_last_point=True).add_to(m)


m.save('animated_user1.html')

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
path1 = './INPUT_FOLDER/E1208.csv'
db = read_csv(path1, sep=';', na_values=".")

# %%
m = folium.Map(
    location=[39.981638,116.342509],
    zoom_start=11
)

marker_cluster = MarkerCluster(
    name='clustered icons',
    overlay=True,
    control=True,
    icon_create_function=None
)
    
for i in range(len(db.Latitude)):
    location = db.Latitude[i], db.Longitude[i]
    marker = folium.Marker(location=location)
    popup = 'Date:{}<br>Time:{}<br>Latitude:{}<br>Longitude:{}'.format(db.Date[i], db.Time[i], db.Latitude[i], db.Longitude[i])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)
m.save('map_user2.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(
    location=[39.981638,116.342509],
    zoom_start=12
)

lines = [
    {
        'coordinates': [
            [116.340965,39.97779],
            [116.344106,39.980635]
        ],
        'dates': [
            '2017-12-16T01:00:33',
            '2017-12-16T01:05:23'
        ],
        'color': 'blue'
    },
    {
        'coordinates': [
            [116.344106,39.980635],
            [116.345811,39.980928]
        ],
        'dates': [
            '2017-12-16T01:05:23',
            '2017-12-16T01:07:43'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            [116.345811,39.980928],
            [116.345531,39.982345]
        ],
        'dates': [
            '2017-12-16T01:07:43',
            '2017-12-16T03:42:56'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.345531,39.982345],
            [116.344465,39.982379]
        ],
        'dates': [
            '2017-12-16T03:42:56',
            '2017-12-16T03:45:01'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            [116.344465,39.982379],
            [116.340291,39.981862]
        ],
        'dates': [
            '2017-12-16T03:45:01',
            '2017-12-16T03:49:11'
        ],
        'color': 'yellow'
    },
    {
        'coordinates': [
            [116.340291,39.981862],
            [116.340291,39.981862]
        ],
        'dates': [
            '2017-12-16T03:49:11',
            '2017-12-16T03:49:11'
        ],
        'color': 'black'
    },
    {
        'coordinates': [
            [116.340291,39.981862],
            [116.338813,39.98118]
        ],
        'dates': [
            '2017-12-16T03:49:11',
            '2017-12-16T03:55:06'
        ],
        'color': 'orange'
    },
    {
        'coordinates': [
            [116.338813,39.98118],
            [116.339637,39.980509]
        ],
        'dates': [
            '2017-12-16T03:55:06',
            '2017-12-16T04:11:36'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.339637,39.980509],
            [116.343793,39.981532]
        ],
        'dates': [
            '2017-12-16T04:11:36',
            '2017-12-16T04:16:06'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.343793,39.981532],
            [116.346284,39.980736]
        ],
        'dates': [
            '2017-12-16T04:16:06',
            '2017-12-16T04:18:56'
        ],
        'color': 'yellow'
    },
    {
        'coordinates': [
            [116.346284,39.980736],
            [116.342509,39.981638]
        ],
        'dates': [
            '2017-12-16T04:18:56',
            '2017-12-16T09:33:42'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.342509,39.981638],
            [116.339833,39.981323]
        ],
        'dates': [
            '2017-12-16T09:33:42',
            '2017-12-16T09:36:02'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.339833,39.981323],
            [116.338837,39.981429]
        ],
        'dates': [
            '2017-12-16T09:36:02',
            '2017-12-16T09:40:02'
        ],
        'color': 'yellow'
    },
    {
        'coordinates': [
            [116.338837,39.981429],
            [116.340839,39.981167]
        ],
        'dates': [
            '2017-12-16T09:40:02',
            '2017-12-16T09:44:07'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.340839,39.981167],
            [116.336765,39.982044]
        ],
        'dates': [
            '2017-12-16T09:44:07',
            '2017-12-16T10:14:37'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.336765,39.982044],
            [116.339483,39.982108]
        ],
        'dates': [
            '2017-12-16T10:14:37',
            '2017-12-16T10:19:32'
        ],
        'color': 'orange'
    },
    {
        'coordinates': [
            [116.339483,39.982108],
            [116.343213,39.981876]
        ],
        'dates': [
            '2017-12-16T10:19:32',
            '2017-12-16T10:24:47'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.343213,39.981876],
            [116.346278,39.980496]
        ],
        'dates': [
            '2017-12-16T10:24:47',
            '2017-12-16T10:28:42'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.346278,39.980496],
            [116.346059,39.980361]
        ],
        'dates': [
            '2017-12-16T10:28:42'
            '2017-12-16T10:39:37'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.346059,39.980361],
            [116.346542,39.981733]
        ],
        'dates': [
            '2017-12-16T10:39:37',
            '2017-12-16T10:43:37'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.346542,39.981733],
            [116.341467,39.983078]
        ],
        'dates': [
            '2017-12-16T10:43:37',
            '2017-12-16T10:47:12'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.341467,39.983078],
            [116.346131,39.981833]
        ],
        'dates': [
            '2017-12-16T10:47:12',
            '2017-12-16T10:50:22'
        ],
        'color': 'orange'
    },
    {
        'coordinates': [
            [116.346131,39.981833],
            [116.346659,39.981891]
        ],
        'dates': [
            '2017-12-16T10:50:22',
            '2017-12-16T10:56:07'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.346659,39.981891],
            [116.346252,39.981739]
        ],
        'dates': [
            '2017-12-16T10:56:07',
            '2017-12-16T10:59:27'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            [116.346252,39.981739],
            [116.345977,39.981535]
        ],
        'dates': [
            '2017-12-16T10:59:27',
            '2017-12-16T11:04:42'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.345977,39.981535],
            [116.344799,39.981593]
        ],
        'dates': [
            '2017-12-16T11:04:42',
            '2017-12-16T11:08:32'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.344799,39.981593],
            [116.346153,39.981692]
        ],
        'dates': [
            '2017-12-16T11:08:32',
            '2017-12-16T11:15:17'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            [116.346153,39.981692],
            [116.346385,39.981837]
        ],
        'dates': [
            '2017-12-16T11:15:17',
            '2017-12-16T11:19:52'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.346385,39.981837],
            [116.346277,39.981993]
        ],
        'dates': [
            '2017-12-16T11:19:52',
            '2017-12-16T11:25:22'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.346277,39.981993],
            [116.346136,39.981963]
        ],
        'dates': [
            '2017-12-16T11:25:22',
            '2017-12-16T11:30:12'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.346136,39.981963],
            [116.346197,39.981698]
        ],
        'dates': [
            '2017-12-16T11:30:12',
            '2017-12-16T11:34:52'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            [116.346197,39.981698],
            [116.346268,39.982106]
        ],
        'dates': [
            '2017-12-16T11:34:52',
            '2017-12-16T11:43:47'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.346268,39.982106],
            [116.346204,39.981764]
        ],
        'dates': [
            '2017-12-16T11:43:47',
            '2017-12-16T11:47:02'
        ],
        'color': 'orange'
    },
    {
        'coordinates': [
            [116.346204,39.981764],
            [116.346159,39.98179]
        ],
        'dates': [
            '2017-12-16T11:47:02',
            '2017-12-16T11:50:22'
        ],
        'color': 'black'
    },
    {
        'coordinates': [
            [116.346159,39.98179],
            [116.346507,39.982035]
        ],
        'dates': [
            '2017-12-16T11:50:22',
            '2017-12-16T11:55:42'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.346507,39.982035],
            [116.346205,39.981934]
        ],
        'dates': [
            '2017-12-16T11:55:42',
            '2017-12-16T11:59:07'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.346205,39.981934],
            [116.346076,39.982089]
        ],
        'dates': [
            '2017-12-16T11:59:07',
            '2017-12-16T12:06:57'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            [116.346076,39.982089],
            [116.346023,39.981673]
        ],
        'dates': [
            '2017-12-16T12:06:57',
            '2017-12-16T12:10:12'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.346023,39.981673],
            [116.346374,39.981819]
        ],
        'dates': [
            '2017-12-16T12:10:12',
            '2017-12-16T12:15:07'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.346374,39.981819],
            [116.345951,39.981902]
        ],
        'dates': [
            '2017-12-16T12:15:07',
            '2017-12-16T12:25:17'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.345951,39.981902],
            [116.346198,39.982003]
        ],
        'dates': [
            '2017-12-16T12:25:17',
            '2017-12-16T12:30:12'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.346198,39.982003],
            [116.346355,39.981681]
        ],
        'dates': [
            '2017-12-16T12:30:12',
            '2017-12-16T12:34:57'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            [116.346355,39.981681],
            [116.34626,39.982048]
        ],
        'dates': [
            '2017-12-16T12:34:57',
            '2017-12-16T12:39:17'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.34626,39.982048],
            [116.346067,39.981851]
        ],
        'dates': [
            '2017-12-16T12:39:17',
            '2017-12-16T12:49:02'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.346067,39.981851],
            [116.346196,39.981811]
        ],
        'dates': [
            '2017-12-16T12:49:02',
            '2017-12-16T12:52:32'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.346196,39.981811],
            [116.346162,39.981916]
        ],
        'dates': [
            '2017-12-16T12:52:32',
            '2017-12-16T12:55:12'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.346162,39.981916],
            [116.346327,39.981815]
        ],
        'dates': [
            '2017-12-16T12:55:12',
            '2017-12-16T13:07:12'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.346327,39.981815],
            [116.345859,39.982192]
        ],
        'dates': [
            '2017-12-16T13:07:12',
            '2017-12-16T13:09:17'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.345859,39.982192],
            [116.346149,39.981719]
        ],
        'dates': [
            '2017-12-16T13:09:17',
            '2017-12-16T13:13:07'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            [116.346149,39.981719],
            [116.346198,39.981804]
        ],
        'dates': [
            '2017-12-16T13:13:07',
            '2017-12-16T13:17:17'
        ],
        'color': 'orange'
    },
    {
        'coordinates': [
            [116.346198,39.981804],
            [116.345713,39.981758]
        ],
        'dates': [
            '2017-12-16T13:17:17',
            '2017-12-16T13:23:37'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.345713,39.981758],
            [116.345931,39.982043]
        ],
        'dates': [
            '2017-12-16T13:23:37',
            '2017-12-16T13:28:07'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.345931,39.982043],
            [116.346369,39.981789]
        ],
        'dates': [
            '2017-12-16T13:28:07',
            '2017-12-16T13:31:32'
        ],
        'color': 'black'
    },
    {
        'coordinates': [
            [116.346369,39.981789],
            [116.346179,39.981755]
        ],
        'dates': [
            '2017-12-16T13:31:32',
            '2017-12-16T13:35:12'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.346179,39.981755],
            [116.345235,39.981365]
        ],
        'dates': [
            '2017-12-16T13:35:12',
            '2017-12-16T13:50:28'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.345235,39.981365],
            [116.346235,39.981816]
        ],
        'dates': [
            '2017-12-16T13:50:28',
            '2017-12-16T13:55:08'
        ],
        'color': 'orange'
    },
    {
        'coordinates': [
            [116.346235,39.981816],
            [116.346113,39.981947]
        ],
        'dates': [
            '2017-12-16T13:55:08',
            '2017-12-16T13:59:33'
        ],
        'color': 'yellow'
    },
    {
        'coordinates': [
            [116.346113,39.981947],
            [116.346347,39.981986]
        ],
        'dates': [
            '2017-12-16T13:59:33',
            '2017-12-16T14:00:59'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.346347,39.981986],
            [116.346311,39.981835]
        ],
        'dates': [
            '2017-12-16T14:00:59',
            '2017-12-16T14:05:34'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.346311,39.981835],
            [116.345945,39.981925]
        ],
        'dates': [
            '2017-12-16T14:05:34',
            '2017-12-16T14:10:54'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.345945,39.981925],
            [116.345962,39.981857]
        ],
        'dates': [
            '2017-12-16T14:10:54',
            '2017-12-16T14:15:59'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.345962,39.981857],
            [116.34589,39.982151]
        ],
        'dates': [
            '2017-12-16T14:15:59',
            '2017-12-16T14:20:19'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.34589,39.982151],
            [116.346008,39.981702]
        ],
        'dates': [
            '2017-12-16T14:20:19',
            '2017-12-16T14:22:24'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            [116.346008,39.981702],
            [116.346147,39.981469]
        ],
        'dates': [
            '2017-12-16T14:22:24',
            '2017-12-16T14:26:14'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.346147,39.981469],
            [116.345882,39.982231]
        ],
        'dates': [
            '2017-12-16T14:26:14',
            '2017-12-16T14:30:24'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.345882,39.982231],
            [116.346315,39.981674]
        ],
        'dates': [
            '2017-12-16T14:30:24',
            '2017-12-16T14:35:24'
        ],
        'color': 'black'
    },
    {
        'coordinates': [
            [116.346315,39.981674],
            [116.345865,39.981927]
        ],
        'dates': [
            '2017-12-16T14:35:24',
            '2017-12-16T14:40:54'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.345865,39.981927],
            [116.345976,39.980993]
        ],
        'dates': [
            '2017-12-16T14:40:54',
            '2017-12-16T14:45:56'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.345976,39.980993],
            [116.345886,39.981504]
        ],
        'dates': [
            '2017-12-16T14:45:56',
            '2017-12-16T14:50:17'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            [116.345886,39.981504],
            [116.345938,39.981384] 
        ],
        'dates': [
            '2017-12-16T14:50:17',
            '2017-12-16T14:52:50'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.345938,39.981384],
            [116.345749,39.981414]
        ],
        'dates': [
            '2017-12-16T14:52:50',
            '2017-12-16T14:56:47'
        ],
        'color': 'black'
    },
    {
        'coordinates': [
            [116.345749,39.981414],
            [116.345895,39.981597]
        ],
        'dates': [
            '2017-12-16T14:56:47',
            '2017-12-16T15:00:58'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.345895,39.981597],
            [116.345876,39.98112]
        ],
        'dates': [
            '2017-12-16T15:00:58',
            '2017-12-16T15:03:13'
        ],
        'color': 'orange'
    },
    {
        'coordinates': [
            [116.345876,39.98112],
            [116.346002,39.980822]
        ],
        'dates': [
            '2017-12-16T15:03:13',
            '2017-12-16T15:15:58'
        ],
        'color': 'red'
    },
    {
        'coordinates': [
            [116.346002,39.980822],
            [116.343778,39.98152]
        ],
        'dates': [
            '2017-12-16T15:15:58',
            '2017-12-16T15:20:34'
        ],
        'color': 'bleu'
    },
    {
        'coordinates': [
            [116.343778,39.98152],
            [116.339661,39.980999]
        ],
        'dates': [
            '2017-12-16T15:20:34',
            '2017-12-16T15:26:59'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            [116.339661,39.980999],
            [116.33879,39.979528]
        ],
        'dates': [
            '2017-12-16T15:26:59',
            '2017-12-16T15:30:59'
        ],
        'color': 'yellow'
    },
    {
        'coordinates': [
            [116.33879,39.979528],
            [116.338886,39.976614]
        ],
        'dates': [
            '2017-12-16T15:30:59',
            '2017-12-16T15:36:09'
        ],
        'color': 'orange'
    },
    {
        'coordinates': [
            [116.338886,39.976614],
            [116.340664,39.976888]
        ],
        'dates': [
            '2017-12-16T15:36:09',
            '2017-12-16T15:48:24'
        ],
        'color': 'green'
    },
    {
        'coordinates': [
            [116.340664,39.976888],
            [116.339135,39.977253]
        ],
        'dates': [
            '2017-12-16T15:48:24',
            '2017-12-16T15:56:59'
        ],
        'color': 'yellow'
    },
    {
        'coordinates': [
            [116.339135,39.977253],
            [116.340451,39.976985]
        ],
        'dates': [
            '2017-12-16T15:56:59',
            '2017-12-16T15:59:34'
        ],
        'color': 'bleu'
    },
    
]


features = [
    {
        'type': 'Feature',
        'geometry': {
            'type': 'LineString',
            'coordinates': line['coordinates'],
        },
        'properties': {
            'times': line['dates'],
            'style': {
                'color': line['color'],
                'weight': line['weight'] if 'weight' in line else 8
            }
        }
    }
    for line in lines
]

plugins.TimestampedGeoJson({
    'type': 'FeatureCollection',
    'features': features,
}, period='PT1M', loop=True, add_last_point=True).add_to(m)


m.save('animated_user2.html')

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
